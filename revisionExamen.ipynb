# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("./ExtraccionDatos/actividad2.3/listings.csv")
df
# Out:
#                        id                                       listing_url  \
# 0                   70820                https://www.airbnb.com/rooms/70820
# 1                  117122               https://www.airbnb.com/rooms/117122
# 2                  176306               https://www.airbnb.com/rooms/176306
# 3                  307634               https://www.airbnb.com/rooms/307634
# 4                  390781               https://www.airbnb.com/rooms/390781
# ...                   ...                                               ...
# 2639  1246838113868532396  https://www.airbnb.com/rooms/1246838113868532396
# 2640  1247069104371725209  https://www.airbnb.com/rooms/1247069104371725209
# 2641  1247178906966071125  https://www.airbnb.com/rooms/1247178906966071125
# 2642  1247202832256700106  https://www.airbnb.com/rooms/1247202832256700106
# 2643  1250666591164917748  https://www.airbnb.com/rooms/1250666591164917748
#
#            scrape_id last_scraped           source  \
# ...

# %% [markdown]
# no tengan mas 2 banos o no sean desde 1 enero 2015 (antes del 1)

# %%
df[["host_since"]] = df[["host_since"]].apply(pd.to_datetime, errors = "coerce")
filtro1  = df[(df["bathrooms"]) <=2 | (df["host_since"] <= "01-01-2015")]
filtro1["bathrooms"]
# Out:
# 2       1.0
# 5       1.0
# 6       1.0
# 7       1.0
# 8       1.0
#        ...
# 2637    1.0
# 2639    1.0
# 2640    1.0
# 2641    1.0
# 2642    1.0
# Name: bathrooms, Length: 1426, dtype: float64
